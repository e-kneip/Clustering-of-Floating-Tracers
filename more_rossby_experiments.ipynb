# %% [markdown]
# More Experiments :) +code of plots in Plots

# %%
from rossby_waves import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
from matplotlib.animation import FuncAnimation, PillowWriter
from rossby_waves.rossby_waves import amplitude, dispersion

# %%
waves = [RossbyWave([10, 0]), RossbyWave([0, 10]), RossbyWave([7, 7])]
oross = RossbyOcean(waves)

ross = RossbyWave([1, 3], 1)

# %%
ross.animate_velocity_divergence(tlim=(0, 9e12, 100))

# %%
oross.animate_velocity_divergence()

# %%
oross = RossbyOcean([RossbyWave([1, 1])])

# %%
oross.add_grid_waves(xlim=(-10, 10, 50), ylim=(-10, 10, 50), phase=True)
oross.remove_wave(0)

# %%
oross.animate_velocity_divergence(tlim=())

# %%
oross.animate_stream_velocity(tlim=(0, 2e13, 100), irrotational=True)

# %%
ross.animate_stream_velocity(tlim=(0, 9e12, 100), solenoidal=True)

# %%
oross.animate_stream_velocity(tlim=(0, 6e12, 100))

# %%
waves = [RossbyWave([10, 0]), RossbyWave([0, 10]), RossbyWave([7, 7])]
oross = RossbyOcean(waves)

ross = RossbyWave([1, 3], 1)

# %%
oross.animate_stream_velocity(tlim=(0, 9e12, 100))

# %%
ross.animate_stream_velocity(tlim=(0, 9e12, 100))

# %%
oross.animate_velocity()

# %%
ross.animate_streamfunction(tlim=(0, 9e12, 100))

# %%
ross.animate_velocity(tlim=(0, 9e12, 100))

# %%
ross.plot_stream_velocity()

# %%
oross.plot_stream_velocity()

# %%
oross.plot_velocity()

# %%
ross.plot_velocity(t=0)

# %%
ross.plot_streamfunction(t=0)

# %%
ross.plot_streamfunction(t=3e13)

# %%
x = np.linspace(-np.pi, np.pi, 21)
y = np.linspace(-np.pi, np.pi, 21)
X, Y = np.meshgrid(x, y)
u, v = ross.velocity(X, Y, t=0)

# %%
ross.velocity(x[0], y[0], 0)
# Out:
# array([16.35759121, -7.3327133 ])

# %%
ross.velocity(x[0], y[0], 1000000000000)
# Out:
# array([ 2.74327154, -1.22974241])

# %%
ou, ov = oross.velocity(X, Y, t=0)

# %%
ross = RossbyWave([5, 10], 2, 2e-11)

# %%
ross.animate_streamfunction()

# %%
waves = [RossbyWave([10, 0]), RossbyWave([0, 10]), RossbyWave([7, 7])]
oross = RossbyOcean(waves)

# %%
oross.animate_streamfunction(tlim=(0, 3e14, 1000), lines=30)

# %%
oross = RossbyOcean([RossbyWave([1, 1])])
oross.add_grid_waves((-10, 10, 21), (-10, 10, 21))
oross.remove_wave(0)

# %%
oross.plot_streamfunction(lines=50)

# %%
oross.animate_streamfunction(tlim=(0, 3e12, 100))
