# %% [markdown]
# Experiments :)

# %%
from rossby_waves import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
from matplotlib.animation import FuncAnimation, PillowWriter
from rossby_waves.rossby_waves import amplitude, dispersion

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z = amplitude([X, Y])
plt.contour(X, Y, Z)
plt.colorbar();

# %%
ross = RossbyWave((5, 10), 2)

# %%
x = np.linspace(-1, 1, 20)
y = np.linspace(-1, 1, 20)
X, Y = np.meshgrid(x, y)
u, v = ross.velocity(X, Y, t=0)

# %%
plt.quiver(X, Y, u, v)

# %%
ross.plot_velocity(density=3)

# %%
ross.plot_velocity(density=3, irrotational=True)

# %%
ross.plot_velocity(density=3, solenoidal=True)

# %%
ross.plot_streamfunction()

# %%
ross.animate_streamfunction(xlim=(-1, 1, 100), ylim=(-2, 2, 200))

# %%
waves = [RossbyWave([10, 0]), RossbyWave([0, 10])]
oross = RossbyOcean(waves)

# %%
oross.plot_velocity()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\elean\Documents\Imperial College London\Mathematics Undergraduate\Year 2\M2R\Clustering-of-Floating-Tracers\rossby_experiments.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/elean/Documents/Imperial%20College%20London/Mathematics%20Undergraduate/Year%202/M2R/Clustering-of-Floating-Tracers/rossby_experiments.ipynb#ch0000092?line=0'>1</a> oross.plot_velocity()
#
# File c:\Users\elean\Documents\Imperial College London\Mathematics Undergraduate\Year 2\M2R\Clustering-of-Floating-Tracers\rossby_waves\rossby_waves.py:325, in RossbyWave.plot_velocity(self, xlim, ylim, t, density, eps, irrotational, solenoidal)
# ...

# %%
oross.plot_streamfunction(xlim=(-np.pi, np.pi, 100), ylim=(-np.pi, np.pi, 100))

# %%
oross.animate_streamfunction(xlim=(-np.pi, np.pi, 100), ylim=(-np.pi, np.pi, 100))

# %%
oross.remove_wave(-1)
oross
# Out:
# RossbyOcean([RossbyWave([10, 0], 0, 1), RossbyWave([0, 10], 0, 1)], 1)

# %%
oross = RossbyOcean([RossbyWave([0,0])])

# %%
oross.add_grid_waves(xlim=(-10, 10, 21), ylim=(-10, 10, 21), phase=True)

# %%
oross.remove_wave(0)

# %%
21 * 10 + 11
# Out:
# 221

# %%
oross.wavevectors[220]
# Out:
# array([0., 0.])

# %%
oross.remove_wave(220)

# %%
oross.plot_streamfunction(xlim=(-np.pi, np.pi, 100), ylim=(-np.pi, np.pi, 100))

# %%
oross.animate_streamfunction(xlim=(-np.pi, np.pi, 100), ylim=(-np.pi, np.pi, 100), tlim=(0, 100, 100))

# %%
oross.add_wave(RossbyWave([7, 7]))
oross.plot_streamfunction(xlim=(-np.pi, np.pi, 100), ylim=(-np.pi, np.pi, 100))

# %%
oross.animate_streamfunction(xlim=(-np.pi, np.pi, 100), ylim=(-np.pi, np.pi, 100))

# %%
ross = RossbyWave([10, 10])
ross.plot_streamfunction(xlim=(-np.pi, np.pi, 100), ylim=(-np.pi, np.pi, 100))

# %%
oross.plot_velocity()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\elean\Documents\Imperial College London\Mathematics Undergraduate\Year 2\M2R\Clustering-of-Floating-Tracers\rossby_experiments.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/elean/Documents/Imperial%20College%20London/Mathematics%20Undergraduate/Year%202/M2R/Clustering-of-Floating-Tracers/rossby_experiments.ipynb#ch0000058?line=0'>1</a> oross.plot_velocity()
#
# File c:\Users\elean\Documents\Imperial College London\Mathematics Undergraduate\Year 2\M2R\Clustering-of-Floating-Tracers\rossby_waves\rossby_waves.py:321, in RossbyWave.plot_velocity(self, xlim, ylim, t, density, eps, irrotational, solenoidal)
# ...

# %%
oross.plot_streamfunction()

# %%
oross.add_random_waves(10)

# %%
oross.plot_streamfunction()

# %%
oross.animate_streamfunction(xlim=(-1, 1, 1000), ylim=(-1, 1, 1000), tlim=(0, 100, 200))

# %%
oross = RossbyOcean([RossbyWave([1, 1])])
oross.add_grid_waves(xlim=(-5, 5, 10), ylim=(-5, 5, 10))
oross.remove_wave(0)

# %%
oross.animate_streamfunction(tlim=(0, 100, 350))

# %%
len(oross.waves)
# Out:
# 10008

# %%
oross.streamfunction(1, 2, 0)
# Out:
# -73.4990048134606

# %%
oross.potentialfunction(1, 2, 0)
# Out:
# -7.349900481346061

# %%
oross.plot_streamfunction()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\elean\Documents\Imperial College London\Mathematics Undergraduate\Year 2\M2R\Clustering-of-Floating-Tracers\rossby_experiments.ipynb Cell 15' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/elean/Documents/Imperial%20College%20London/Mathematics%20Undergraduate/Year%202/M2R/Clustering-of-Floating-Tracers/rossby_experiments.ipynb#ch0000008?line=0'>1</a> oross.plot_streamfunction()
#
# AttributeError: 'RossbyOcean' object has no attribute 'plot_streamfunction'

# %%
xlim=np.linspace(-5, 5, 10)
ylim=np.linspace(-5, 5, 10)
X, Y = np.meshgrid(xlim, ylim)

# %%
a = np.array([[1, 1], [1,2], [2,3]])
b = a.transpose()
dispersion(b, 1)
# Out:
# array([-0.5       , -0.2       , -0.15384615])

# %%
dispersion(np.array([1, 1]), 1)
# Out:
# -0.5

# %%
a[:, 1]
# Out:
# array([1, 2, 3])

# %%
a[:, 1] + dispersion(b, 1)
# Out:
# array([0.5       , 1.8       , 2.84615385])
